# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from math import log, sqrt, exp, pi, cos
from pynverse import inversefunc

# from scipy import stats as st
import seaborn as sns
sns.set(color_codes=True)

sns.set_palette(sns.color_palette("Set2"))
sns.set(rc={'figure.figsize':(10,8)}, style="white", color_codes=True)


import warnings
warnings.filterwarnings("ignore")

# %%
def f3(x):
    if (x >= -math.pi / 2 and x <= math.pi / 2):
        return (13/(12*math.pi)) - (x**2/math.pi**3)
    else:
        return 0
    

f3x_values = lambda x: f3(x)

x = np.linspace(-2, 2, 1024)
y = [f3x_values(i) for i in x]

plt.ylim(-.1, 0.5)
plt.plot(x,y)
# Grafico de f - Punto A
plt.show()

# %%
# Hallar F, F-1 y graficar - Punto B

def F3(x):
    if (x < -math.pi / 2):
        return 0
    if (x >= -math.pi / 2 and x <= math.pi / 2):
        return ((13 * x)/(12 * math.pi)) - ((x ** 3) / (3 * (math.pi ** 3)))
    if (x > math.pi / 2):
        return 1
    
F3x_values = lambda x: F3(x)

x = np.linspace(-2, 2, 100000)
y = [F3x_values(i) for i in x]

plt.plot(x,y)
